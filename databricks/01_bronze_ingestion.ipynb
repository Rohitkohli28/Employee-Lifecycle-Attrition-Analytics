# %%
display(
    dbutils.fs.ls("abfss://raw@strohitattrition01.dfs.core.windows.net/")
)

# %%
df = spark.read \
    .option("header", "true") \
    .csv("abfss://raw@strohitattrition01.dfs.core.windows.net/*/")

# %%
print(df.count())
display(df)

# %%
from pyspark.sql.functions import input_file_name

df = df.withColumn("source_file", input_file_name())

# %%
df.printSchema()

# %%
display(df.limit(5))

# %%
display(
    spark.read.option("header","true").csv("abfss://raw@strohitattrition01.dfs.core.windows.net/day1/")
)

# %%
spark.read.option("header","true").csv("abfss://raw@strohitattrition01.dfs.core.windows.net/day1/").printSchema()

# %%
df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("bronze_employee")

# %%
bronze_df = spark.table("bronze_employee")
display(bronze_df)

# %%
print(bronze_df.count())
